# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from env import host, user, password
import acquire
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %% [markdown]
# The objective of this notebook is to inspect the dataset and see if:
# - 1.) There is any duplicate values, not in every field but where it would matter.
# - 2.) Look for duplicate fields and drop those who are repeated.
# - 3.) Inspect fields which could be split into a numerical category.
# - 4.) Create dummy variables for those fields we wish to split into a numeric category.
# - 5.) Add the dummy columns to the original df!
# - 6.) Generate functions within this notebook which will be implemented with in the prepare.py
# - 7.) Give a few charts to display data. Pre-exploratory!!!

# %%
telco_churn = acquire.get_telco_churn_data()

# %% [markdown]
# ### Summarize our data:
# - head(), describe(), info(), isnull(), value_counts(), shape, ...
# - plt.hist(), plt.boxplot()
# - document takeaways (nulls, datatypes to change, outliers, ideas for features, etc.)

# %% [markdown]
# Import the data and inspect it for nulls, duplicate values and columns, review the data types.

# %%
telco_churn.head(2)
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0057-QBUQH  Female               0      No        Yes      43
# 1  0106-UGRDO  Female               0     Yes         No      69
#
#   phone_service multiple_lines internet_service_type_id      online_security  \
# 0           Yes            Yes                        3  No internet service
# 1           Yes            Yes                        2                  Yes
#
#    ...  payment_type_id monthly_charges total_charges churn contract_type_id  \
# 0  ...                1            25.1       1070.15    No                3
# 1  ...                1           116.0       8182.85    No                3
#
#    contract_type internet_service_type_id  internet_service_type  \
# 0       Two year                        3                   None
# 1       Two year                        3                   None
#
#    payment_type_id      payment_type
# 0                1  Electronic check
# 1                1  Electronic check
#
# [2 rows x 27 columns]

# %%
# Displaying all of the datasets columns.
telco_churn.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents',
#        'tenure', 'phone_service', 'multiple_lines', 'internet_service_type_id',
#        'online_security', 'online_backup', 'device_protection', 'tech_support',
#        'streaming_tv', 'streaming_movies', 'contract_type_id',
#        'paperless_billing', 'payment_type_id', 'monthly_charges',
#        'total_charges', 'churn', 'contract_type_id', 'contract_type',
#        'internet_service_type_id', 'internet_service_type', 'payment_type_id',
#        'payment_type'],
#       dtype='object')

# %%
# start looking into the dataset.
telco_churn.info()
# appears there is no nulls within the data set. Need to check and make sure no values are nan as well!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   senior_citizen            7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   tenure                    7043 non-null   int64
#  6   phone_service             7043 non-null   object
#  7   multiple_lines            7043 non-null   object
#  8   internet_service_type_id  7043 non-null   int64
#  9   online_security           7043 non-null   object
#  10  online_backup             7043 non-null   object
#  11  device_protection         7043 non-null   object
#  12  tech_support              7043 non-null   object
#  13  streaming_tv              7043 non-null   object
#  14  streaming_movies          7043 non-null   object
#  15  contract_type_id          7043 non-null   int64
#  16  paperless_billing         7043 non-null   object
#  17  payment_type_id           7043 non-null   int64
#  18  monthly_charges           7043 non-null   float64
#  19  total_charges             7043 non-null   object
#  20  churn                     7043 non-null   object
#  21  contract_type_id          7043 non-null   int64
#  22  contract_type             7043 non-null   object
#  23  internet_service_type_id  7043 non-null   int64
#  24  internet_service_type     7043 non-null   object
#  25  payment_type_id           7043 non-null   int64
#  26  payment_type              7043 non-null   object
# dtypes: float64(1), int64(8), object(18)
# memory usage: 1.5+ MB

# %%
telco_drop = telco_churn.drop_duplicates(inplace = True)

# %%
telco_churn.set_index('customer_id', drop = True, inplace = True)

# %%
telco_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0057-QBUQH to 9974-JFBHQ
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    7043 non-null   object
#  1   senior_citizen            7043 non-null   int64
#  2   partner                   7043 non-null   object
#  3   dependents                7043 non-null   object
#  4   tenure                    7043 non-null   int64
#  5   phone_service             7043 non-null   object
#  6   multiple_lines            7043 non-null   object
#  7   internet_service_type_id  7043 non-null   int64
#  8   online_security           7043 non-null   object
#  9   online_backup             7043 non-null   object
#  10  device_protection         7043 non-null   object
#  11  tech_support              7043 non-null   object
#  12  streaming_tv              7043 non-null   object
#  13  streaming_movies          7043 non-null   object
#  14  contract_type_id          7043 non-null   int64
#  15  paperless_billing         7043 non-null   object
#  16  payment_type_id           7043 non-null   int64
#  17  monthly_charges           7043 non-null   float64
#  18  total_charges             7043 non-null   object
#  19  churn                     7043 non-null   object
#  20  contract_type_id          7043 non-null   int64
#  21  contract_type             7043 non-null   object
#  22  internet_service_type_id  7043 non-null   int64
#  23  internet_service_type     7043 non-null   object
#  24  payment_type_id           7043 non-null   int64
#  25  payment_type              7043 non-null   object
# dtypes: float64(1), int64(8), object(17)
# memory usage: 1.5+ MB

# %%
#are there any empty records??
telco_churn.replace(' ', np.nan, inplace = True)

# %%
#double checking the dataset for nulls
# appears total charges has 11 nan values.
nan_check = telco_churn.isna().sum()

# %%
#dropped the nan values within the total charges column
telco_churn.dropna(inplace =True)
telco_churn.count()
# Out:
# gender                      7032
# senior_citizen              7032
# partner                     7032
# dependents                  7032
# tenure                      7032
# phone_service               7032
# multiple_lines              7032
# internet_service_type_id    7032
# online_security             7032
# online_backup               7032
# device_protection           7032
# tech_support                7032
# streaming_tv                7032
# streaming_movies            7032
# contract_type_id            7032
# paperless_billing           7032
# payment_type_id             7032
# monthly_charges             7032
# total_charges               7032
# churn                       7032
# contract_type_id            7032
# contract_type               7032
# internet_service_type_id    7032
# internet_service_type       7032
# payment_type_id             7032
# payment_type                7032
# dtype: int64

# %%
# statistical details of the dataset.
telco_churn.describe().T
# Out:
#                            count       mean        std    min      25%    50%  \
# senior_citizen            7032.0   0.162400   0.368844   0.00   0.0000   0.00
# tenure                    7032.0  32.421786  24.545260   1.00   9.0000  29.00
# internet_service_type_id  7032.0   1.872582   0.737271   1.00   1.0000   2.00
# contract_type_id          7032.0   1.688567   0.832934   1.00   1.0000   1.00
# payment_type_id           7032.0   2.315557   1.149523   1.00   1.0000   2.00
# monthly_charges           7032.0  64.798208  30.085974  18.25  35.5875  70.35
# contract_type_id          7032.0   1.688567   0.832934   1.00   1.0000   1.00
# internet_service_type_id  7032.0   1.688567   0.832934   1.00   1.0000   1.00
# payment_type_id           7032.0   2.315557   1.149523   1.00   1.0000   2.00
#
#                               75%     max
# senior_citizen             0.0000    1.00
# tenure                    55.0000   72.00
# internet_service_type_id   2.0000    3.00
# contract_type_id           2.0000    3.00
# payment_type_id            3.0000    4.00
# monthly_charges           89.8625  118.75
# contract_type_id           2.0000    3.00
# internet_service_type_id   2.0000    3.00
# payment_type_id            3.0000    4.00

# %% [markdown]
# ## Begin cleaning up the table and data

# %%
# dropped duplicate columns.
telco_churn = telco_churn.loc[:, ~telco_churn.columns.duplicated()]

# %%
telco_churn = telco_churn.astype({'total_charges': 'float64'})

# %%
telco_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0057-QBUQH to 9974-JFBHQ
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    7032 non-null   object
#  1   senior_citizen            7032 non-null   int64
#  2   partner                   7032 non-null   object
#  3   dependents                7032 non-null   object
#  4   tenure                    7032 non-null   int64
#  5   phone_service             7032 non-null   object
#  6   multiple_lines            7032 non-null   object
#  7   internet_service_type_id  7032 non-null   int64
#  8   online_security           7032 non-null   object
#  9   online_backup             7032 non-null   object
#  10  device_protection         7032 non-null   object
#  11  tech_support              7032 non-null   object
#  12  streaming_tv              7032 non-null   object
#  13  streaming_movies          7032 non-null   object
#  14  contract_type_id          7032 non-null   int64
#  15  paperless_billing         7032 non-null   object
#  16  payment_type_id           7032 non-null   int64
#  17  monthly_charges           7032 non-null   float64
#  18  total_charges             7032 non-null   float64
#  19  churn                     7032 non-null   object
#  20  contract_type             7032 non-null   object
#  21  internet_service_type     7032 non-null   object
#  22  payment_type              7032 non-null   object
# dtypes: float64(2), int64(5), object(16)
# memory usage: 1.3+ MB

# %%
telco_churn.head().T
# Out:
# customer_id                        0057-QBUQH        0106-UGRDO  \
# gender                                 Female            Female
# senior_citizen                              0                 0
# partner                                    No               Yes
# dependents                                Yes                No
# tenure                                     43                69
# phone_service                             Yes               Yes
# multiple_lines                            Yes               Yes
# internet_service_type_id                    3                 2
# online_security           No internet service               Yes
# online_backup             No internet service               Yes
# device_protection         No internet service               Yes
# tech_support              No internet service               Yes
# streaming_tv              No internet service               Yes
# streaming_movies          No internet service               Yes
# contract_type_id                            3                 3
# paperless_billing                         Yes               Yes
# payment_type_id                             1                 1
# monthly_charges                          25.1               116
# total_charges                         1070.15           8182.85
# churn                                      No                No
# contract_type                        Two year          Two year
# internet_service_type                    None              None
# payment_type                 Electronic check  Electronic check
#
# customer_id                     0136-IFMYD        0164-APGRB        0253-ZTEOB
# gender                                Male            Female            Female
# senior_citizen                           1                 0                 0
# partner                                Yes                No               Yes
# dependents                              No                No               Yes
# tenure                                  69                72                48
# phone_service                          Yes               Yes               Yes
# multiple_lines                         Yes               Yes               Yes
# internet_service_type_id                 2                 2                 1
# online_security                         No               Yes                No
# online_backup                          Yes               Yes               Yes
# device_protection                      Yes               Yes                No
# tech_support                           Yes               Yes               Yes
# streaming_tv                           Yes               Yes               Yes
# streaming_movies                       Yes               Yes               Yes
# contract_type_id                         3                 3                 3
# paperless_billing                      Yes               Yes                No
# payment_type_id                          1                 1                 1
# monthly_charges                     109.95             114.9             79.65
# total_charges                      7634.25            8496.7            3870.3
# churn                                   No                No                No
# contract_type                     Two year          Two year          Two year
# internet_service_type                 None              None              None
# payment_type              Electronic check  Electronic check  Electronic check

# %%
telco_churn.multiple_lines.value_counts()
# Out:
# No                  3385
# Yes                 2967
# No phone service     680
# Name: multiple_lines, dtype: int64

# %%
telco_churn.gender = telco_churn.gender.replace({'Female': 1, 'Male':0})
telco_churn.partner = telco_churn.partner.replace({'Yes': 1, 'No':0})
telco_churn.dependents = telco_churn.dependents.replace({'Yes': 1, 'No':0})

# %%
telco_churn.phone_service= telco_churn.phone_service.replace({'Yes': 1, 'No':0})
telco_churn.multiple_lines = telco_churn.multiple_lines.replace({'Yes': 1, 'No':0, 'No phone service': 2})

# %%
telco_churn.online_security = telco_churn.online_security.replace({'Yes': 1, 'No':0, 'No internet service': 2})

# %%
telco_churn.online_backup = telco_churn.online_backup.replace({'Yes': 1, 'No':0, 'No internet service': 2})

# %%
telco_churn.device_protection = telco_churn.device_protection.replace({'Yes': 1, 'No':0, 'No internet service': 2})

# %%
telco_churn.tech_support = telco_churn.tech_support.replace({'Yes': 1, 'No':0, 'No internet service': 2})

# %%
telco_churn.streaming_tv = telco_churn.streaming_tv.replace({'Yes': 1, 'No':0, 'No internet service': 2})

# %%
telco_churn.streaming_movies = telco_churn.streaming_movies.replace({'Yes': 1, 'No':0, 'No internet service': 2})

# %%
telco_churn.paperless_billing = telco_churn.paperless_billing.replace({'Yes': 1, 'No':0})

# %%
telco_churn.contract_type = telco_churn.contract_type.replace({'Month-to-month': 0, 'One Year':1, 'Two year': 2})

# %%
telco_churn.internet_service_type = telco_churn.internet_service_type.replace({'None': 0, 'DSL':1, 'Fiber optic': 2})

# %%
telco_churn.payment_type = telco_churn.payment_type.replace({'Bank transfer (automatic)': 0, 'Credit card (automatic)':1, 'Electronic check': 2, 'Mailed check': 3})

# %%
telco_churn.churn = telco_churn.churn.replace({'Yes': 1, 'No':0})

# %%
telco_churn.head(4)
# Out:
#              gender  senior_citizen  partner  dependents  tenure  \
# customer_id
# 0057-QBUQH        1               0        0           1      43
# 0106-UGRDO        1               0        1           0      69
# 0136-IFMYD        0               1        1           0      69
# 0164-APGRB        1               0        0           0      72
#
#              phone_service  multiple_lines  internet_service_type_id  \
# customer_id
# 0057-QBUQH               1               1                         3
# 0106-UGRDO               1               1                         2
# 0136-IFMYD               1               1                         2
# 0164-APGRB               1               1                         2
#
#              online_security  online_backup  ...  streaming_movies  \
# customer_id                                  ...
# 0057-QBUQH                 2              2  ...                 2
# 0106-UGRDO                 1              1  ...                 1
# 0136-IFMYD                 0              1  ...                 1
# 0164-APGRB                 1              1  ...                 1
#
#              contract_type_id  paperless_billing  payment_type_id  \
# customer_id
# 0057-QBUQH                  3                  1                1
# 0106-UGRDO                  3                  1                1
# 0136-IFMYD                  3                  1                1
# 0164-APGRB                  3                  1                1
#
#              monthly_charges  total_charges  churn  contract_type  \
# customer_id
# 0057-QBUQH             25.10        1070.15      0              2
# 0106-UGRDO            116.00        8182.85      0              2
# 0136-IFMYD            109.95        7634.25      0              2
# 0164-APGRB            114.90        8496.70      0              2
#
#              internet_service_type  payment_type
# customer_id
# 0057-QBUQH                       0             2
# 0106-UGRDO                       0             2
# 0136-IFMYD                       0             2
# 0164-APGRB                       0             2
#
# [4 rows x 23 columns]

# %% [markdown]
# ## Creating simple charts to evaluate the data and see if there is any relationships.

# %%
#Numeric features
numeric = ['monthly_charges', 'total_charges']
num_cols = telco_churn[numeric]

# %%
#Categorical features
object_cols = telco_churn.drop(columns = ['monthly_charges', 'total_charges'])

# %%
# Look at the value count for each categorical feature.
for col in object_cols:
    print(col)
    print(telco_churn[col].value_counts())
    print('------------------------------------------------')
# Out:
# gender
# 0    3549
# 1    3483
# Name: gender, dtype: int64
# ------------------------------------------------
# senior_citizen
# 0    5890
# 1    1142
# Name: senior_citizen, dtype: int64
# ------------------------------------------------
# partner
# 0    3639
# 1    3393
# Name: partner, dtype: int64
# ------------------------------------------------
# dependents
# 0    4933
# 1    2099
# Name: dependents, dtype: int64
# ------------------------------------------------
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# Name: tenure, Length: 72, dtype: int64
# ------------------------------------------------
# phone_service
# 1    6352
# 0     680
# Name: phone_service, dtype: int64
# ------------------------------------------------
# multiple_lines
# 0    3385
# 1    2967
# 2     680
# Name: multiple_lines, dtype: int64
# ------------------------------------------------
# internet_service_type_id
# 2    3096
# 1    2416
# 3    1520
# Name: internet_service_type_id, dtype: int64
# ------------------------------------------------
# online_security
# 0    3497
# 1    2015
# 2    1520
# Name: online_security, dtype: int64
# ------------------------------------------------
# online_backup
# 0    3087
# 1    2425
# 2    1520
# Name: online_backup, dtype: int64
# ------------------------------------------------
# device_protection
# 0    3094
# 1    2418
# 2    1520
# Name: device_protection, dtype: int64
# ------------------------------------------------
# tech_support
# 0    3472
# 1    2040
# 2    1520
# Name: tech_support, dtype: int64
# ------------------------------------------------
# streaming_tv
# 0    2809
# 1    2703
# 2    1520
# Name: streaming_tv, dtype: int64
# ------------------------------------------------
# streaming_movies
# 0    2781
# 1    2731
# 2    1520
# Name: streaming_movies, dtype: int64
# ------------------------------------------------
# contract_type_id
# 1    3875
# 3    1685
# 2    1472
# Name: contract_type_id, dtype: int64
# ------------------------------------------------
# paperless_billing
# 1    4168
# 0    2864
# Name: paperless_billing, dtype: int64
# ------------------------------------------------
# payment_type_id
# 1    2365
# 2    1604
# 3    1542
# 4    1521
# Name: payment_type_id, dtype: int64
# ------------------------------------------------
# churn
# 0    5163
# 1    1869
# Name: churn, dtype: int64
# ------------------------------------------------
# contract_type
# 0           3875
# 2           1685
# One year    1472
# Name: contract_type, dtype: int64
# ------------------------------------------------
# internet_service_type
# 1    3875
# 0    1685
# 2    1472
# Name: internet_service_type, dtype: int64
# ------------------------------------------------
# payment_type
# 2    2365
# 3    1604
# 0    1542
# 1    1521
# Name: payment_type, dtype: int64
# ------------------------------------------------

# %%
#created list of categorical columns which excluded customer id.

# %%
# want to change columns with yes and no to numeric 0 and 1

# %%
# using above variables to see value counts for each column.
